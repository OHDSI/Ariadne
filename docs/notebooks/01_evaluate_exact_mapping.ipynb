# %% [markdown]
# # Evaluation of the exact matching pipeline
#
# Here we evaluate the performance on the task of finding exact matches of source terms to standard concepts in the OHDSI Vocabulary.
# For this we use a gold standard dataset of source terms with their correct mappings to standard concepts, with some source terms not having any correct mapping.
#
# ![Notebook diagram](../assets/AriadneDiagram.png)
#
# ## Setup
#
# Before running this notebook, make sure the environment is set up as described in the README.
# This includes credentials for a database with the OHDSI Vocabulary loaded, and credentials for the LLM API.
# The prompts, as specified in `config_condition_mapping.yaml`, are tailored for **GPT o3**, so we recommend using that model for this evaluation.
# This notebook currently assumes the use of a local PGVector instance for vector search, instantiated with the code at [https://github.com/schuemie/OhdsiVocabVectorStore](https://github.com/schuemie/OhdsiVocabVectorStore), but an option to use the public OHDSI Hecate vector search API is also available.
#
# All results will be stored in the `data/notebook_results` folder.
# Most code blocks will load results from file if they already exist, to save time and costs.
# Delete those files to rerun the corresponding steps.

# %%
from pathlib import Path
import pandas as pd
from dotenv import load_dotenv

from ariadne.utils.config import Config

project_root = Path.cwd().parent.parent
load_dotenv()

config = Config()

# %% [markdown]
# ## Gold standard
#
# We use the gold standard file in the `data/gold_standards` folder.

# %%
gold_standard_path = project_root / "data" / "gold_standards" / "exact_matching_gs.csv"

gold_standard = pd.read_csv(gold_standard_path)
gold_standard.head()
# Out:
#    source_code                                        source_term  \
# 0         8690  Unspecified enthesopathy, lower limb, excludin...
# 1         9724       Lead-induced chronic gout, unspecified elbow
# 2         9770  Chronic gout due to renal impairment, right elbow
# 3         9946                  Pathological fracture, left ankle
# 4        10389                      Unspecified fracture of skull
#
#    target_concept_id                         target_concept_name   predicate  \
# 0            4116324  Enthesopathy of lower leg and ankle region  exactMatch
# 1             607432                 Chronic gout caused by lead  broadMatch
# 2           46270464       Gout of elbow due to renal impairment  broadMatch
# 3             760649         Pathological fracture of left ankle  exactMatch
# 4            4324690                           Fracture of skull  exactMatch
#
#    target_concept_id_b                       target_concept_name_b predicate_b
# 0            4116324.0  Enthesopathy of lower leg and ankle region  broadMatch
# 1                  NaN                                         NaN         NaN
# 2                  NaN                                         NaN         NaN
# 3                  NaN                                         NaN         NaN
# 4                  NaN                                         NaN         NaN

# %% [markdown]
# This gold standard contains the following columns:
#  - `source_code`: the concept ID of the source term (non-standard concept)
#   - `source_term`: the source term text
#   - `standard_concept_id`: the concept ID of the standard concept to which the source term maps
#   - `standard_concept_name`: the name of the standard concept
#   - `predicate`: Whether the mapping is an `exactMatch` or a `broadMatch`. Only `exactMatch` mappings are considered correct in this evaluation.
#   - `target_concept_id_b`, `target_concept_name_b`, and `predicate_b`: optional second mapping for the source term that is equally valid, if available.
#
# ## Term cleanup
#
# The first step is to clean up the source terms, removing any extraneous information that may interfere with matching.
# This includes removing phrases like "not otherwise specified", as well as other uninformative parts of the source term.
# This step uses the LLM to perform the cleanup.
# The `TermCleaner` class handles this, using the system prompts specified in the `config_condition_mapping.yaml` file, and adds a `cleaned_term` column to the input DataFrame.

# %%
from ariadne.term_cleanup.term_cleaner import TermCleaner

cleaned_terms_file = project_root / "data" / "notebook_results" / "exact_matching_cleaned_terms.csv"
if cleaned_terms_file.exists():
    cleaned_terms = pd.read_csv(cleaned_terms_file)
    print("Loaded cleaned terms from file.")
else:
    term_cleaner = TermCleaner(config.term_cleaning)
    cleaned_terms = term_cleaner.clean_terms(gold_standard)
    print(f"Total LLM cost: ${term_cleaner.get_total_cost():.6f}")
cleaned_terms.to_csv(cleaned_terms_file, index=False)


cleaned_terms[["source_term", "cleaned_term"]].head(10)
# Out:
# Loaded cleaned terms from file.
#                                          source_term  \
# 0  Unspecified enthesopathy, lower limb, excludin...
# 1       Lead-induced chronic gout, unspecified elbow
# 2  Chronic gout due to renal impairment, right elbow
# 3                  Pathological fracture, left ankle
# 4                      Unspecified fracture of skull
# 5  Ocular laceration without prolapse or loss of ...
# 6  Penetrating wound of orbit with or without for...
# 7  Fracture of unspecified shoulder girdle, part ...
# 8  Drowning and submersion due to falling or jump...
# 9  Alcohol use, unspecified with withdrawal delirium
#
#                                         cleaned_term
# 0           enthesopathy, lower limb, excluding foot
# 1                   lead-induced chronic gout, elbow
# 2  chronic gout due to renal impairment, right elbow
# 3                  pathological fracture, left ankle
# 4                                  fracture of skull
# 5  ocular laceration without prolapse or loss of ...
# 6                         penetrating wound of orbit
# 7                        fracture of shoulder girdle
# 8  drowning and submersion due to falling or jump...
# 9               alcohol use with withdrawal delirium

# %% [markdown]
# ## Verbatim matching
#
# The next step is to perform verbatim matching, i.e. looking for exact matches of the cleaned source terms in the vocabulary.
# We do allow for some minor variations, such as case differences and punctuation differences.
#
# We use the `VocabVerbatimTermMapper` class for this, which first needs to create an index of the vocabulary terms.
# For this it will connect to the database specified in the environment variables.
# It will restrict to the vocabularies and domains specified in the `config_condition_mapping.yaml` file.
# This adds the `mapped_concept_id` and `mapped_concept_name` columns to the input DataFrame.

# %%
from ariadne.verbatim_mapping.term_downloader import download_terms
from ariadne.verbatim_mapping.vocab_verbatim_term_mapper import VocabVerbatimTermMapper

verbatim_match_file = project_root / "data" / "notebook_results" / "exact_matching_verbatim_maps.csv"
if verbatim_match_file.exists():
    verbatim_matches = pd.read_csv(verbatim_match_file)
    print("Loaded verbatim matches from file.")
else:
    download_terms(config.verbatim_mapping) # Downloads the terms as Parquet files
    verbatim_mapper = VocabVerbatimTermMapper(config.verbatim_mapping) # Will construct the vocabulary index if needed
    verbatim_matches = verbatim_mapper.map_terms(cleaned_terms)
    verbatim_matches.to_csv(verbatim_match_file, index=False)
verbatim_matches[["source_term", "cleaned_term", "mapped_concept_id", "mapped_concept_name"]].head(10)
# Out:
# Starting downloading terms
# Downloaded 100000 rows, total downloaded: 100000
# Downloaded 100000 rows, total downloaded: 200000
# Downloaded 100000 rows, total downloaded: 300000
# Downloaded 100000 rows, total downloaded: 400000
# Downloaded 100000 rows, total downloaded: 500000
# Downloaded 100000 rows, total downloaded: 600000
# Downloaded 100000 rows, total downloaded: 700000
# Downloaded 100000 rows, total downloaded: 800000
# Downloaded 100000 rows, total downloaded: 900000
# Downloaded 100000 rows, total downloaded: 1000000
# Downloaded 100000 rows, total downloaded: 1100000
# Downloaded 100000 rows, total downloaded: 1200000
# Downloaded 100000 rows, total downloaded: 1300000
# Downloaded 100000 rows, total downloaded: 1400000
# Downloaded 100000 rows, total downloaded: 1500000
# Downloaded 100000 rows, total downloaded: 1600000
# Downloaded 100000 rows, total downloaded: 1700000
# Downloaded 100000 rows, total downloaded: 1800000
# Downloaded 100000 rows, total downloaded: 1900000
# Downloaded 100000 rows, total downloaded: 2000000
# Downloaded 100000 rows, total downloaded: 2100000
# Downloaded 100000 rows, total downloaded: 2200000
# Downloaded 100000 rows, total downloaded: 2300000
# Downloaded 100000 rows, total downloaded: 2400000
# Downloaded 100000 rows, total downloaded: 2500000
# Downloaded 100000 rows, total downloaded: 2600000
# Downloaded 100000 rows, total downloaded: 2700000
# Downloaded 100000 rows, total downloaded: 2800000
# Downloaded 100000 rows, total downloaded: 2900000
# Downloaded 100000 rows, total downloaded: 3000000
# Downloaded 100000 rows, total downloaded: 3100000
# Downloaded 95441 rows, total downloaded: 3195441
# Finished downloading terms
# spaCy model 'en_core_web_sm' loaded successfully.
# Creating index
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1000001_1100000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_100001_200000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1100001_1200000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1200001_1300000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1300001_1400000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1400001_1500000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1500001_1600000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1600001_1700000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1700001_1800000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1800001_1900000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1900001_2000000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_1_100000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2000001_2100000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_200001_300000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2100001_2200000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2200001_2300000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2300001_2400000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2400001_2500000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2500001_2600000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2600001_2700000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2700001_2800000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2800001_2900000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_2900001_3000000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_3000001_3100000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_300001_400000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_3100001_3195441.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_400001_500000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_500001_600000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_600001_700000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_700001_800000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_800001_900000.parquet
# Processing file: E:\git\Ariadne\data\terms_condition_mapping\Terms_900001_1000000.parquet
# Index saved to E:\git\Ariadne\data\verbatim_condition_mapping_index.pkl
#                                          source_term  \
# 0  Unspecified enthesopathy, lower limb, excludin...
# 1       Lead-induced chronic gout, unspecified elbow
# 2  Chronic gout due to renal impairment, right elbow
# 3                  Pathological fracture, left ankle
# 4                      Unspecified fracture of skull
# 5  Ocular laceration without prolapse or loss of ...
# 6  Penetrating wound of orbit with or without for...
# 7  Fracture of unspecified shoulder girdle, part ...
# 8  Drowning and submersion due to falling or jump...
# 9  Alcohol use, unspecified with withdrawal delirium
#
#                                         cleaned_term  mapped_concept_id  \
# 0           enthesopathy, lower limb, excluding foot                 -1
# 1                   lead-induced chronic gout, elbow                 -1
# 2  chronic gout due to renal impairment, right elbow                 -1
# 3                  pathological fracture, left ankle                 -1
# 4                                  fracture of skull            4324690
# 5  ocular laceration without prolapse or loss of ...                 -1
# 6                         penetrating wound of orbit            4334734
# 7                        fracture of shoulder girdle                 -1
# 8  drowning and submersion due to falling or jump...                 -1
# 9               alcohol use with withdrawal delirium                 -1
#
#           mapped_concept_name
# 0
# 1
# 2
# 3
# 4           Fracture of skull
# 5
# 6  Penetrating wound of orbit
# 7
# 8
# 9

# %% [markdown]
# ## Embedding vector search
#
# Next, we perform embedding vector search for the source terms that were not matched by verbatim matching.
# This uses the vector store specified in the `config_condition_mapping.yaml` file, which can be either a local PGVector instance or the OHDSI Hecate API.

# %%
from ariadne.vector_search.pgvector_concept_searcher import PgvectorConceptSearcher
# from ariadne.vector_search.hecate_concept_searcher import HecateConceptSearcher

vector_search_results_file = project_root / "data" / "notebook_results" / "exact_matching_vector_search_results.csv"
if vector_search_results_file.exists():
    vector_search_results = pd.read_csv(vector_search_results_file)
    print("Loaded vector search results from file.")
else:
    concept_searcher = PgvectorConceptSearcher()
    # concept_searcher = HecateConceptSearcher()
    unmatched_terms = cleaned_terms.copy()
    unmatched_terms = unmatched_terms[unmatched_terms["source_code"].isin(
        verbatim_matches["source_code"][verbatim_matches["mapped_concept_id"] == -1]
    )]
    vector_search_results = concept_searcher.search_terms(
        unmatched_terms, term_column="cleaned_term"
    )
    vector_search_results.to_csv(vector_search_results_file, index=False)
vector_search_results[["source_term", "cleaned_term", "matched_concept_id", "matched_concept_name", "match_score"]].head(10)
# Out:
# Getting embedding vectors for batch 1 - 100 (460 total)
# HTTP Request: POST https://genaiapimna.jnj.com/openai-embeddings/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Getting embedding vectors for batch 101 - 200 (460 total)
# HTTP Request: POST https://genaiapimna.jnj.com/openai-embeddings/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Getting embedding vectors for batch 201 - 300 (460 total)
# HTTP Request: POST https://genaiapimna.jnj.com/openai-embeddings/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Getting embedding vectors for batch 301 - 400 (460 total)
# HTTP Request: POST https://genaiapimna.jnj.com/openai-embeddings/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Getting embedding vectors for batch 401 - 460 (460 total)
# HTTP Request: POST https://genaiapimna.jnj.com/openai-embeddings/openai/deployments/text-embedding-3-large/embeddings?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# Cell In[7], line 15
#      11     unmatched_terms = cleaned_terms.copy()
#      12     unmatched_terms = unmatched_terms[unmatched_terms["source_code"].isin(
#      13         verbatim_matches["source_code"][verbatim_matches["mapped_concept_id"] == -1]
#      14     )]
# ---> 15     vector_search_results = concept_searcher.search_terms(
#      16         unmatched_terms, term_column="cleaned_term"
#      17     )
#      18     vector_search_results.to_csv(vector_search_results_file, index=False)
#      19 vector_search_results[["source_term", "cleaned_term", "matched_concept_id", "matched_concept_name", "match_score"]].head(10)
#
# File E:\git\Ariadne\src\ariadne\vector_search\pgvector_concept_searcher.py:267, in PgvectorConceptSearcher.search_terms(self, df, term_column, matched_concept_id_column, matched_concept_name_column, match_score_column, match_rank_column, limit, return_embeddings)
#     265 if return_embeddings:
#     266     term_to_vector[term] = vector
# --> 267 results = self._search_pgvector(vector, limit=limit)
#     268 results = pd.DataFrame(
#     269     results,
#     270     columns=[
#    (...)    274     ],
#     275 )
#     276 results[match_rank_column] = range(1, len(results) + 1)
#
# File E:\git\Ariadne\src\ariadne\vector_search\pgvector_concept_searcher.py:153, in PgvectorConceptSearcher._search_pgvector(self, source_vector, limit)
#     101     query = f"""
#     102         WITH target_concept AS (
#     103             SELECT concept_id,
#    (...)    150         LIMIT {limit};
#     151     """
#     152     with self.connection.cursor() as cur:
# --> 153         cur.execute(query, (source_vector, source_vector, source_vector, source_vector))
#     154         results = cur.fetchall()
#     155 else:
#
# File E:\git\Ariadne\venv\Lib\site-packages\psycopg\cursor.py:117, in Cursor.execute(self, query, params, prepare, binary)
#     113         self._conn.wait(
#     114             self._execute_gen(query, params, prepare=prepare, binary=binary)
#     115         )
#     116 except e._NO_TRACEBACK as ex:
# --> 117     raise ex.with_traceback(None)
#     118 return self
#
# UndefinedTable: relation "vocabulary_feb2026.concept_vector" does not exist
# LINE 11:                             FROM vocabulary_feb2026.concept_...
#                                           ^

# %% [markdown]
# ### Evaluating the vector search results
#
# We can now evaluate the vector search results on their own, before combining them with the verbatim matches.
# The results are written to a text file that contains overall statistics as well as detailed per-term results.

# %%
from ariadne.evaluation.concept_search_evaluator import evaluate_concept_search

evaluate_concept_search(
    search_results=vector_search_results,
    output_file=project_root / "data" / "notebook_results" / "exact_matching_vector_search_evaluation.txt",
)

with open(project_root / "data" / "notebook_results" / "exact_matching_vector_search_evaluation.txt", "r") as f:
    evaluation_text = f.read()
print("\n".join(evaluation_text.split("\n")[:15]))
# Out:
# Evaluation complete. Results written to /Users/aostrop1/Library/CloudStorage/OneDrive-JNJ/projects/aostropolets_git/Ariadne/data/notebook_results/exact_matching_vector_search_evaluation.txt
# Evaluated gold standard concepts: 334
# Mean Average Precision: 0.8724197263735833
# Recall@1: 0.8053892215568862
# Recall@3: 0.9311377245508982
# Recall@10: 0.9790419161676647
# Recall@25: 0.9970059880239521
#
# Source term: Unspecified enthesopathy, lower limb, excluding foot (8690)
# Searched term: enthesopathy, lower limb, excluding foot
# Gold standard concept rank: 6
#
#  match_rank Correct  matched_concept_id                       matched_concept_name
#           1                     4194889                 Enthesopathy of lower limb
#           2                    46284922                   Enthesitis of lower limb
#           3                      198846                 Enthesopathy of hip region

# %% [markdown]
# ## LLM exact matching
#
# Finally, we perform LLM-based exact matching for the source terms that were not matched by verbatim matching, by choosing from a set of candidate concepts retrieved by vector search.
#
# ### Retrieving concept context
#
# We observed the LLM does require some context about the target concepts, including the parents, children, and synonyms, to make good mapping decisions.
# We must therefore retrieve this context from the database before passing it to the LLM.

# %%
from ariadne.llm_mapping.concept_context_retriever import add_concept_context

context_file_name = project_root / "data" / "notebook_results" / "exact_matching_vector_search_context.csv"
if context_file_name.exists():
    vector_search_results_context = pd.read_csv(context_file_name)
    print("Loaded vector search context from file.")
else:
    vector_search_results_context = add_concept_context(vector_search_results)
    vector_search_results_context.to_csv(context_file_name, index=False)
vector_search_results_context[["source_term", "matched_concept_id", "matched_concept_name", "matched_synonyms", "matched_concept_class_id", "matched_children"]].head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 10
#       8     vector_search_results_context = add_concept_context(vector_search_results)
#       9     vector_search_results_context.to_csv(context_file_name, index=False)
# ---> 10 vector_search_results[["source_term", "matched_concept_id", "matched_concept_name", "matched_synonyms", "matched_concept_class_id", "matched_children"]].head(10)
#
# File ~/Library/CloudStorage/OneDrive-JNJ/projects/aostropolets_git/Ariadne/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Library/CloudStorage/OneDrive-JNJ/projects/aostropolets_git/Ariadne/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/Library/CloudStorage/OneDrive-JNJ/projects/aostropolets_git/Ariadne/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['matched_synonyms', 'matched_concept_class_id', 'matched_children'] not in index"

# %% [markdown]
# ### LLM mapping
#
# Now we can perform the LLM-based exact matching.
# This uses the system prompts specified in the `config_condition_mapping.yaml` file, which are tailored for **GPT o3**.
# LLM responses are cached to avoid duplicate costs when rerunning.

# %%
from ariadne.llm_mapping.llm_mapper import LlmMapper

llm_mapper = LlmMapper()
mapped_terms = llm_mapper.map_terms(vector_search_results_context)

llm_mapped_terms_file = project_root / "data" / "notebook_results" / "exact_matching_llm_mapped_terms.csv"
mapped_terms.to_csv(llm_mapped_terms_file, index=False)
print(f"Total LLM cost: ${llm_mapper.get_total_cost():.6f}")
mapped_terms[["source_term", "cleaned_term", "mapped_concept_id", "mapped_concept_name"]].head(10)
# Out:
# Total LLM cost: $0.000000
#                                          source_term  \
# 0                              AV block first degree
# 1           Abnormal findings in cerebrospinal fluid
# 2  Abnormal findings in cerebrospinal fluid, Abno...
# 3  Abnormal microbiological findings in specimens...
# 4  Surgical operation with formation of external ...
# 5                        Abnormalities of heart beat
# 6  Abscess of breast associated with pregnancy, u...
# 7             Abscess of bursa, right ankle and foot
# 8         Accidents caused by transmission machinery
# 9                                     Acn� excori�e
#
#                                         cleaned_term  mapped_concept_id  \
# 0                              AV block first degree             314379
# 1           Abnormal findings in cerebrospinal fluid            4065770
# 2  Abnormal findings in cerebrospinal fluid, Abno...            4172064
# 3  Abnormal microbiological findings in specimens...            4171911
# 4  Abnormal reaction or later complication due to...            4123283
# 5                        Abnormalities of heart beat            4262562
# 6        Abscess of breast associated with pregnancy              78218
# 7             Abscess of bursa, right ankle and foot                 -1
# 8         Accidents caused by transmission machinery             439456
# 9                                     Acn� excori�e             4004094
#
#                                  mapped_concept_name
# 0                First degree atrioventricular block
# 1           Cerebrospinal fluid examination abnormal
# 2              Abnormal histological findings in CSF
# 3  Abnormal microbiological finding in specimen f...
# 4                                  Disorder of stoma
# 5                                Abnormal heart beat
# 6  Obstetric breast abscess with antenatal compli...
# 7                                           no_match
# 8    Accident caused by power transmission machinery
# 9                                    Excoriated acne

# %% [markdown]
# ## Final evaluation
# Now we can combine the verbatim matches and the LLM-based matches, and evaluate the overall performance.

# %%
from ariadne.evaluation.concept_selection_evaluator import evaluate

# Combine verbatim matches and LLM matches
# First take all verbatim matches that were successful
final_mapped_terms = verbatim_matches[verbatim_matches["mapped_concept_id"] != -1][
    ["source_concept_id", "source_term", "cleaned_term", "mapped_concept_id", "mapped_concept_name"]
].copy()
final_mapped_terms["map_method"] = "verbatim"

# Then add the LLM matches (for the terms that were not verbatim matched)
llm_mapped_terms_filtered = mapped_terms[
    ["source_concept_id", "source_term", "cleaned_term", "mapped_concept_id", "mapped_concept_name", "mapped_rationale"]
].copy()
llm_mapped_terms_filtered["map_method"] = "llm"
final_mapped_terms = pd.concat([final_mapped_terms, llm_mapped_terms_filtered], ignore_index=True)

# Evaluate
final_evaluation_results = evaluate(final_mapped_terms)
final_evaluation_results.to_csv(project_root / "data" / "notebook_results" / "exact_matching_final_evaluation.csv", index=False)

final_evaluation_results[["source_term", "target_concept_name", "map_method", "mapped_concept_name", "is_correct"]].head()
# Out:
#                                          source_term  \
# 0                      Unspecified fracture of skull
# 1  Penetrating wound of orbit with or without for...
# 2  Other retinal disorders in diseases classified...
# 3                     Other forms of angina pectoris
# 4        Other forms of acute ischemic heart disease
#
#             target_concept_name map_method           mapped_concept_name  \
# 0             Fracture of skull   verbatim             Fracture of skull
# 1    Penetrating wound of orbit   verbatim    Penetrating wound of orbit
# 2              Retinal disorder   verbatim              Retinal disorder
# 3               Angina pectoris   verbatim               Angina pectoris
# 4  Acute ischemic heart disease   verbatim  Acute ischemic heart disease
#
#    is_correct
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True

# %%
overall_accuracy = final_evaluation_results["is_correct"].mean()
print(f"Overall accuracy: {overall_accuracy:.4f}")
# Out:
# Overall accuracy: 0.8836

# %%
# Zip data/llm_responses folder to data/notebook_results/llm_responses.zip
import shutil
shutil.make_archive(
    project_root / "data" / "notebook_results" / "llm_responses",
    'zip',
    project_root / "data" / "llm_mapper_responses"
)
print("Zipped LLM responses.")
# Out:
# Zipped LLM responses.
